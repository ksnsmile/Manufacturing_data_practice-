# %%
import pandas as pd

df1=pd.read_csv("C:/Users/sn714/OneDrive/바탕 화면/git/Manufacturing/data/preprocessing_data.csv")

df1.head(3)
# Out:
#    Unnamed: 0  Ox_Chamber    process type    Temp_OXid Vapor    ppm  Pressure  \
# 0           0           1  Oxidation  dry  1138.979159    O2  32.80     0.200
# 1           1           1  Oxidation  dry  1218.184551    O2  31.86     0.194
# 2           2           1  Oxidation  dry  1062.467808    O2  39.51     0.217
#
#    Oxid_time  thickness  ...      Flux480s      Flux840s  input_Energy  \
# 0       62.0    699.443  ...  3.002593e+17  6.000007e+17     31574.410
# 1      137.0    696.792  ...  3.017903e+17  6.000012e+17     31580.213
# 2      128.0    705.471  ...  2.994231e+17  6.000002e+17     32162.414
#
#    Temp_implantation Furance_Temp  RTA_Temp  Target  Error_message  \
# 0            102.847        885.0       154      96           none
# 1            104.323        919.0       154     102           none
# 2            100.605        916.0       155      95           none
#
#    target_binom  Chamber_Route
# 0           0.0    route_11133
# 1           0.0    route_11222
# 2           0.0    route_11311
#
# [3 rows x 60 columns]

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Ox_Chamber', 'process', 'type', 'Temp_OXid', 'Vapor',
#        'ppm', 'Pressure', 'Oxid_time', 'thickness', 'No_Die', 'Reinforcement',
#        'Unnamed: 0_x', 'photo_soft_Chamber', 'process 2', 'resist_target',
#        'N2_HMDS', 'pressure_HMDS', 'temp_HMDS', 'temp_HMDS_bake',
#        'time_HMDS_bake', 'spin1', 'spin2', 'spin3', 'photoresist_bake',
#        'temp_softbake', 'time_softbake', 'lithography_Chamber', 'Line_CD',
#        'UV_type', 'Wavelength', 'Resolution', 'Energy_Exposure', 'Range_check',
#        'Unnamed: 0_y', 'Etching_Chamber', 'Process 3', 'Temp_Etching',
#        'Source_Power', 'Selectivity', 'Thin Film 4', 'Thin Film 3',
#        'Thin Film 2', 'Thin Film 1', 'Etching_rate', 'Chamber_Num', 'process4',
#        'Flux60s', 'Flux90s', 'Flux160s', 'Flux480s', 'Flux840s',
#        'input_Energy', 'Temp_implantation', 'Furance_Temp', 'RTA_Temp',
#        'Target', 'Error_message', 'target_binom', 'Chamber_Route'],
#       dtype='object')

# %%
df1['Target']
# Out:
# 0       96
# 1      102
# 2       95
# 3      117
# 4      143
#       ...
# 747     84
# 748    105
# 749     78
# 750     42
# 751     84
# Name: Target, Length: 752, dtype: int64

# %%
Y=df1['Target'] #wafer에 불량이라고 판단 된 칩의 개수

X=df1[['Temp_OXid','Oxid_time','thickness','Line_CD','Etching_rate','Temp_Etching']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y,random_state=1234)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (564, 6)
# (188, 6)
# (564,)
# (188,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
y_train_predict=model.predict(X_train)
y_test_predict=model.predict(X_test)

# %%
r2_score(y_train,y_train_predict)
# Out:
# 0.34582379022991816

# %%
r2_score(y_test,y_test_predict)
# Out:
# 0.29396801142541706

# %%
def evaluation_reg(model):
    y_train_predict=model.predict(X_train)
    y_test_predict=model.predict(X_test)
    print("학습 데이터 결정계수 : ", r2_score(y_train,y_train_predict))
    print("검증 데이터 결정계수 : ", r2_score(y_test,y_test_predict))
    print("학습 데이터 MSE : ", mean_squared_error(y_train,y_train_predict))
    print("검증 데이터 MSE : ", mean_squared_error(y_train,y_train_predict))

# %%
evaluation_reg(model)
# Out:
# 학습 데이터 결정계수 :  0.34582379022991816
# 검증 데이터 결정계수 :  0.29396801142541706
# 학습 데이터 MSE :  2684.9553213362337
# 검증 데이터 MSE :  2684.9553213362337

# %% [markdown]
# # 특성공학 기법 적용
#
# - pipe line : 학습과 특성공학(결측치 제거,변형 ,추가,스케일링, 인코딩 ) 기법을 동시에 사용하여, 데이터를 한꺼번에 처리하면서 학습을 수행하는 함수

# %%
from sklearn.pipeline import Pipeline # 학습 + 특성공학
from sklearn.impute import SimpleImputer #결측값 처리 함수

# %%
pipe_list=[('imputer',SimpleImputer()),
           ('model', LinearRegression() )]

pipe_model=Pipeline(pipe_list)

# %%
pipe_model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()), ('model', LinearRegression())])

# %%
evaluation_reg(pipe_model)
# Out:
# 학습 데이터 결정계수 :  0.34582379022991816
# 검증 데이터 결정계수 :  0.29396801142541706
# 학습 데이터 MSE :  2684.9553213362337
# 검증 데이터 MSE :  2684.9553213362337

# %% [markdown]
# **새로운 값을 직접 입력하여 예측**

# %%
x1=input("Temp_OXid을 입력하시오 : ")
x2=input("Oxid_time을 입력하시오 : ")
x3=input("thickness을 입력하시오 : " )
x4=input("Line_CD을 입력하시오 : " )
x5=input("Etching_rate을 입력하시오 : " )
x6=input("Temp_Etching을 입력하시오 : " )
# Out:
# Temp_OXid을 입력하시오 :  1
# Oxid_time을 입력하시오 :  2
# thickness을 입력하시오 :  3
# Line_CD을 입력하시오 :  4
# Etching_rate을 입력하시오 :  5
# Temp_Etching을 입력하시오 :  6

# %%
input_new_data=pd.DataFrame([[x1,x2,x3,x4,x5,x6]])

# %%
pipe_model.predict(input_new_data)
# Out:
# C:\Users\sn714\AppData\Local\anaconda3\envs\data\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([1626.77140627])

# %% [markdown]
# ***결측값이 있어도 pipeline을 구축하여서 예상되어 출력된다.***

# %%
import numpy as np

# %%
input_new_data2=pd.DataFrame([[x1,np.nan,x3,x4,x5,x6]],columns=X.columns.tolist())
input_new_data2
# Out:
#   Temp_OXid  Oxid_time thickness Line_CD Etching_rate Temp_Etching
# 0         1        NaN         3       4            5            6

# %%
pipe_model.predict(input_new_data2)
# Out:
# array([1637.64316555])

# %% [markdown]
# **Scaling & Encoding**
#
# -scaling > 연속형
#
# -Encoding > 범주형
#
# -imputation > 연속/범주

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Ox_Chamber', 'process', 'type', 'Temp_OXid', 'Vapor',
#        'ppm', 'Pressure', 'Oxid_time', 'thickness', 'No_Die', 'Reinforcement',
#        'Unnamed: 0_x', 'photo_soft_Chamber', 'process 2', 'resist_target',
#        'N2_HMDS', 'pressure_HMDS', 'temp_HMDS', 'temp_HMDS_bake',
#        'time_HMDS_bake', 'spin1', 'spin2', 'spin3', 'photoresist_bake',
#        'temp_softbake', 'time_softbake', 'lithography_Chamber', 'Line_CD',
#        'UV_type', 'Wavelength', 'Resolution', 'Energy_Exposure', 'Range_check',
#        'Unnamed: 0_y', 'Etching_Chamber', 'Process 3', 'Temp_Etching',
#        'Source_Power', 'Selectivity', 'Thin Film 4', 'Thin Film 3',
#        'Thin Film 2', 'Thin Film 1', 'Etching_rate', 'Chamber_Num', 'process4',
#        'Flux60s', 'Flux90s', 'Flux160s', 'Flux480s', 'Flux840s',
#        'input_Energy', 'Temp_implantation', 'Furance_Temp', 'RTA_Temp',
#        'Target', 'Error_message', 'target_binom', 'Chamber_Route'],
#       dtype='object')

# %%
Y=df1['Target']
X=df1[['Oxid_time','thickness','Vapor','resist_target','Line_CD','Etching_rate','UV_type']]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=1234)

# %%
#문자데이터와 숫자데이터를 구분하여 처리하는 프로세스를 구축할 때 사용하는 함수

from sklearn.compose import make_column_transformer # 특성공학 + 학습
from sklearn.pipeline import make_pipeline #scaling & Encoding
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder

# %%
#연속형/범주형 데이터 항목명을 리스트로 선언

numeric_list=['Oxid_time','thickness','resist_target','Line_CD','Etching_rate']

category_list=['Vapor','UV_type']

# %%
#연속형 데이터가 처리되는 process (결측값을 평균으로 대체한다음 스케일을 최소0 최대 1로 변환)

numeric_pipe=make_pipeline(SimpleImputer(strategy='mean'), MinMaxScaler())

# %%
#범주형 데이터가 처리되는 process ( 결측값을 최빈값으로 대치한 다음, 문자데이터를 onehot인코딩 변환)

category_pipe=make_pipeline(SimpleImputer(strategy="most_frequent"),OneHotEncoder())

# %%
#연속형과 범주형을 나누어 처리하는 pipe를 구성

preprocessing_pipe=make_column_transformer((numeric_pipe,numeric_list),
                        (category_pipe,category_list))

pipe_model=make_pipeline(preprocessing_pipe,LinearRegression())

# %%
print(pipe_model)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('minmaxscaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Oxid_time', 'thickness',
#                                                    'resist_target', 'Line_CD',
#                                                    'Etching_rate']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Vapor', 'UV_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
import numpy as np
pipe_model.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('minmaxscaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Oxid_time', 'thickness',
#                                                    'resist_target', 'Line_CD',
#                                                    'Etching_rate']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Vapor', 'UV_type'])])),
#                 ('linearregression', LinearRegression())])

# %% [markdown]
# **교차 검증 Cross Validation**

# %%
from sklearn.model_selection import GridSearchCV

# %%
# 5회의 교차검증 pipe model의 process를 따라가며 학습  학습데이터를 5번 쪼개면서 학습

grid_model=GridSearchCV(pipe_model, param_grid={}, cv=5)
grid_model.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('minmaxscaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['Oxid_time',
#                                                                           'thickness',
#                                                                           'resist_target',
#                                                                           'Line_CD',
#                                                                           'Etching_rate']),
#                                                                         ('pipeline-2',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehotencoder',
#                                                                                           OneHotEncoder())]),
#                                                                          ['Vapor',
#                                                                           'UV_type'])])),
#                                        ('linearregression',
#                                         LinearRegression())]),
#              param_grid={})

# %%
best_model=grid_model.best_estimator_

# %%
evaluation_reg(best_model)
# Out:
# 학습 데이터 결정계수 :  0.3804084568229765
# 검증 데이터 결정계수 :  0.2871965092882167
# 학습 데이터 MSE :  2543.0084219858154
# 검증 데이터 MSE :  2543.0084219858154

# %% [markdown]
# **Hyper Parameter Tuning**

# %%
#의사결정나무 알고리즘

from sklearn.tree import DecisionTreeRegressor

# %%
#연속형과 범주형을 나누어 처리하는 pipe를 구성

preprocessing_pipe=make_column_transformer((numeric_pipe,numeric_list),
                        (category_pipe,category_list))

pipe_model=make_pipeline(preprocessing_pipe,DecisionTreeRegressor())

# %%
pipe_model
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('minmaxscaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Oxid_time', 'thickness',
#                                                    'resist_target', 'Line_CD',
#                                                    'Etching_rate']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Vapor', 'UV_type'])])),
#                 ('decisiontreeregressor', DecisionTreeRegressor())])

# %%
hyperparameter={'decisiontreeregressor__max_depth' : range(5,11),
               'decisiontreeregressor__min_samples_split':range(1,11),
               'decisiontreeregressor__min_samples_leaf':range(5,11)}

grid_model=GridSearchCV(pipe_model,param_grid=hyperparameter,cv=5)
#5회의 교차검증 수행
grid_model.fit(X_train,Y_train)
# Out:
# C:\Users\sn714\AppData\Local\anaconda3\envs\data\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 180 fits failed out of a total of 1800.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sn714\AppData\Local\anaconda3\envs\data\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sn714\AppData\Local\anaconda3\envs\data\lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\sn714\AppData\Local\anaconda3\envs\data\lib\site-packages\sklearn\pipeline.py", line 473, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "C:\Users\sn714\AppData\Local\anaconda3\envs\data\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\sn714\AppData\Local\anaconda3\envs\data\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sn714\AppData\Local\anaconda3\envs\data\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeRegressor must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\sn714\AppData\Local\anaconda3\envs\data\lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan 0.28114358 0.28114358 0.28114358 0.28114358 0.28114358
#  0.28114358 0.28114358 0.28114358 0.28114358        nan 0.26927114
#  0.26927114 0.26927114 0.26927114 0.26927114 0.26927114 0.26927114
#  0.26927114 0.26927114        nan 0.26446005 0.26446005 0.26446005
#  0.26446005 0.26446005 0.26446005 0.26446005 0.26446005 0.26446005
#         nan 0.25964486 0.25964486 0.25964486 0.25964486 0.25964486
#  0.25964486 0.25964486 0.25964486 0.25964486        nan 0.25584335
#  0.25584335 0.25584335 0.25584335 0.25584335 0.25584335 0.25584335
#  0.25584335 0.25584335        nan 0.26299308 0.26299308 0.26299308
#  0.26299308 0.26299308 0.26299308 0.26299308 0.26299308 0.26299308
#         nan 0.25375979 0.25375979 0.25375979 0.25375979 0.25375979
#  0.25375979 0.25375979 0.25375979 0.25375979        nan 0.24785455
#  0.24785455 0.24785455 0.24785455 0.24785455 0.24785455 0.24785455
#  0.24785455 0.24785455        nan 0.23922094 0.23649176 0.23649176
#  0.23922094 0.23649176 0.23865649 0.23922094 0.23649176 0.23865649
#         nan 0.2451139  0.24454944 0.2451139  0.2451139  0.24454944
#  0.24454944 0.24454944 0.2451139  0.24454944        nan 0.25155328
#  0.25155328 0.25098883 0.25098883 0.25098883 0.25098883 0.25155328
#  0.25098883 0.25098883        nan 0.24940837 0.24997282 0.24940837
#  0.24997282 0.24997282 0.24997282 0.24940837 0.24997282 0.24997282
#         nan 0.21704038 0.21704038 0.21704038 0.21704038 0.2214879
#  0.21704038 0.2214879  0.21704038 0.21704038        nan 0.2066837
#  0.2066837  0.2066837  0.2066837  0.21113122 0.2066837  0.21113122
#  0.2066837  0.21113122        nan 0.21696502 0.21615931 0.2174179
#  0.21822361 0.21809816 0.21890388 0.21622078 0.21696502 0.21696502
#         nan 0.22343093 0.22343093 0.22409232 0.22343093 0.22409232
#  0.22343093 0.22343093 0.22409232 0.22343093        nan 0.22928576
#  0.22991776 0.22928576 0.22991776 0.22991776 0.22991776 0.22928576
#  0.22991776 0.22991776        nan 0.22432515 0.22432515 0.22432515
#  0.22432515 0.22432515 0.22432515 0.22432515 0.22369315 0.22432515
#         nan 0.16941503 0.16620289 0.16620289 0.17065041 0.17386256
#  0.16941503 0.17386256 0.17386256 0.16941503        nan 0.18925457
#  0.18480704 0.18480704 0.18925457 0.18925457 0.18480704 0.18925457
#  0.18925457 0.18925457        nan 0.20817684 0.20741795 0.20891858
#  0.20823831 0.20817684 0.20691825 0.20823831 0.20615935 0.20697972
#         nan 0.22650016 0.22648767 0.22650016 0.22650016 0.22648767
#  0.22648767 0.22650016 0.22650016 0.22650016        nan 0.23607878
#  0.23671078 0.23671078 0.23607878 0.23607878 0.23671078 0.23607878
#  0.23671078 0.23607878        nan 0.22122764 0.22059564 0.22122764
#  0.22059564 0.22059564 0.22059564 0.22122764 0.22059564 0.22122764
#         nan 0.15979019 0.15657804 0.15657804 0.15979019 0.15979019
#  0.15657804 0.15213052 0.15979019 0.15979019        nan 0.17744947
#  0.18189699 0.18189699 0.18189699 0.18189699 0.18189699 0.17744947
#  0.18189699 0.17744947        nan 0.20280758 0.20342637 0.20230789
#  0.20424674 0.20418527 0.20280758 0.20274611 0.20154899 0.20154899
#         nan 0.22265272 0.22264023 0.22265272 0.22265272 0.22265272
#  0.22264023 0.22264023 0.22265272 0.22264023        nan 0.24107158
#  0.24107158 0.24043958 0.24107158 0.24107158 0.24107158 0.24107158
#  0.24043958 0.24043958        nan 0.22233143 0.22296343 0.22233143
#  0.22296343 0.22233143 0.22233143 0.22233143 0.22296343 0.22233143
#         nan 0.14343628 0.14664842 0.14333797 0.15099764 0.15099764
#  0.15109595 0.14664842 0.14664842 0.15099764        nan 0.1724326
#  0.17688013 0.1724326  0.1724326  0.17688013 0.17688013 0.1724326
#  0.17688013 0.17688013        nan 0.19677155 0.19683302 0.19745181
#  0.19677155 0.19475406 0.19557443 0.19677155 0.19745181 0.19669292
#         nan 0.21729247 0.21730497 0.21730497 0.21729247 0.21730497
#  0.21730497 0.21729247 0.21729247 0.21729247        nan 0.23851424
#  0.23788224 0.23851424 0.23788224 0.23851424 0.23851424 0.23788224
#  0.23788224 0.23788224        nan 0.22231953 0.22168753 0.22231953
#  0.22231953 0.22231953 0.22231953 0.22168753 0.22231953 0.22168753]
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('minmaxscaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['Oxid_time',
#                                                                           'thickness',
#                                                                           'resist_target',
#                                                                           'Line_CD',
#                                                                           'Etching_rate']),
#                                                                         ('pipeline-2',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehotencoder',
#                                                                                           OneHotEncoder())]),
#                                                                          ['Vapor',
#                                                                           'UV_type'])])),
#                                        ('decisiontreeregressor',
#                                         DecisionTreeRegressor())]),
#              param_grid={'decisiontreeregressor__max_depth': range(5, 11),
#                          'decisiontreeregressor__min_samples_leaf': range(5, 11),
#                          'decisiontreeregressor__min_samples_split': range(1, 11)})

# %%
best_model=grid_model.best_estimator_
best_model
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('minmaxscaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Oxid_time', 'thickness',
#                                                    'resist_target', 'Line_CD',
#                                                    'Etching_rate']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Vapor', 'UV_type'])])),
#                 ('decisiontreeregressor',
#                  DecisionTreeRegressor(max_depth=5, min_samples_leaf=5))])

# %%
evaluation_reg(best_model)
# Out:
# 학습 데이터 결정계수 :  0.6071143811638606
# 검증 데이터 결정계수 :  -0.14097311763387732
# 학습 데이터 MSE :  1612.532399093697
# 검증 데이터 MSE :  1612.532399093697

# %% [markdown]
# ### 특성공학
#
# - imputation(결측값 처리)
#
# - Scaling & Encoding
#
# - Cross Validation
#
# - Hyper parameter Tuning
#
# - Imbalanced Data Sampling(분류)
